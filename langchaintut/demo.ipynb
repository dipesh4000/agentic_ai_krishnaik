# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
print("-" * 50 + "\n" + "Environment variables set successfully!" + "\n" + "-" * 50)
# Out:
# --------------------------------------------------
# Environment variables set successfully!
# --------------------------------------------------

# %%
from langchain.chat_models import init_chat_model
model_gemini = init_chat_model("google_genai:gemini-2.5-flash-lite")
# model_gemini.invoke([{"role": "user", "content": "What is the process of getting into AiML?"}]).content

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model_groq = init_chat_model("groq:qwen/qwen3-32b")
# response = model_groq.invoke("Why do parrots talk?")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
# Out:
# <generator object BaseChatModel.stream at 0x000002B32318BA60>

# %%
from IPython.display import display, Markdown

for fl in model.stream("What is the process of getting into Ai? Explain in 50 words"):
    display(Markdown(fl.text))
# Out:
# To
#  enter AI, gain foundational knowledge in math (calculus, linear algebra, probability) and computer
#  science. Learn programming languages like Python. Study machine learning, deep learning, and relevant AI subfields. Build projects and contribute to open-source to gain practical experience and demonstrate your skills.
